# %%
import os
import math
import folium
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon

from utils import *

# %%
d = {
    'id': [1, 2, 3, 4], 
    'longitude': [-73.589462, -73.590055, -73.590041, -73.589008],
    'latitude': [45.592012, 45.592189, 45.592181, 45.590781],
    'poly_id': [99, 99, 99, 99]
}
df = pd.DataFrame(data=d)

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf
# Out:
#    id  longitude   latitude  poly_id                    geometry
# 0   1 -73.589462  45.592012       99  POINT (-73.58946 45.59201)
# 1   2 -73.590055  45.592189       99  POINT (-73.59006 45.59219)
# 2   3 -73.590041  45.592181       99  POINT (-73.59004 45.59218)
# 3   4 -73.589008  45.590781       99  POINT (-73.58901 45.59078)

# %% [raw]
# In this code, we first create a KDTree from the geometry of the GeoDataFrame. We then use the query method of the tree to find the closest point to each point in the GeoDataFrame, with k=2 so that the closest point is itself. Finally, we use the indices returned by the query to create a new column in the GeoDataFrame containing the closest point for each row.

# %%
from scipy.spatial import cKDTree
import numpy as np

# Create a KDTree from the geometry of the GeoDataFrame
tree = cKDTree(np.array(gdf.geometry.apply(lambda geom: [geom.x, geom.y])).tolist())

# Query the tree for the closest points to each point in the GeoDataFrame
distances, indices = tree.query(np.array(gdf.geometry.apply(lambda geom: [geom.x, geom.y])).tolist(), k=2)

# Get the closest point for each row
gdf['closest_point'] = gdf.geometry.iloc[indices[:, 1]].values

# %%
gdf
# Out:
#    id  longitude   latitude  poly_id                    geometry  \
# 0   1 -73.589462  45.592012       99  POINT (-73.58946 45.59201)
# 1   2 -73.590055  45.592189       99  POINT (-73.59006 45.59219)
# 2   3 -73.590041  45.592181       99  POINT (-73.59004 45.59218)
# 3   4 -73.589008  45.590781       99  POINT (-73.58901 45.59078)
#
#                 closest_point
# 0  POINT (-73.59004 45.59218)
# 1  POINT (-73.59004 45.59218)
# 2  POINT (-73.59006 45.59219)
# 3  POINT (-73.58946 45.59201)

# %%
m = folium.Map(location=[45.5414195, -73.6303031], tiles="cartodbpositron", zoom_start=12)

# %%
for _, row in gdf.iterrows():
    lat = row.latitude
    lon = row.longitude
    folium.Marker(location=[lat, lon], popup=row["id"]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57265822c32fc3202879fe0ba665c51f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57265822c32fc3202879fe0ba665c51f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57265822c32fc3202879fe0ba665c51f = L.map(
#                 &quot;map_57265822c32fc3202879fe0ba665c51f&quot;,
#                 {
#                     center: [45.5414195, -73.6303031],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6913e981afe571f1ac02869bc3a99299 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57265822c32fc3202879fe0ba665c51f);
#
#
#             var marker_bfa1a9cb21625ab648f57237b5755d61 = L.marker(
#                 [45.592012, -73.589462],
#                 {}
#             ).addTo(map_57265822c32fc3202879fe0ba665c51f);
#
#
#         var popup_3c6b23f76a20028c510e3fe394f3bf2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_259fbd3207a123f99ad5f72144c39b82 = $(`&lt;div id=&quot;html_259fbd3207a123f99ad5f72144c39b82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_3c6b23f76a20028c510e3fe394f3bf2b.setContent(html_259fbd3207a123f99ad5f72144c39b82);
#
#
#
#         marker_bfa1a9cb21625ab648f57237b5755d61.bindPopup(popup_3c6b23f76a20028c510e3fe394f3bf2b)
#         ;
#
#
#
#
#             var marker_e7781574251c32c8fc03345a8e388f23 = L.marker(
#                 [45.592189, -73.590055],
#                 {}
#             ).addTo(map_57265822c32fc3202879fe0ba665c51f);
#
#
#         var popup_dd49645a827d8bf35b95ed09f4c62dd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_779bba13cf5f7478be1d1075718a20bb = $(`&lt;div id=&quot;html_779bba13cf5f7478be1d1075718a20bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_dd49645a827d8bf35b95ed09f4c62dd7.setContent(html_779bba13cf5f7478be1d1075718a20bb);
#
#
#
#         marker_e7781574251c32c8fc03345a8e388f23.bindPopup(popup_dd49645a827d8bf35b95ed09f4c62dd7)
#         ;
#
#
#
#
#             var marker_1e91552b8aa0dc7ac686086a74626bf2 = L.marker(
#                 [45.592181, -73.590041],
#                 {}
#             ).addTo(map_57265822c32fc3202879fe0ba665c51f);
#
#
#         var popup_4396d00f18ba2d16e1a89ea3044166e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9aeee7ad23a7230bd75fe68c81a9799d = $(`&lt;div id=&quot;html_9aeee7ad23a7230bd75fe68c81a9799d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_4396d00f18ba2d16e1a89ea3044166e6.setContent(html_9aeee7ad23a7230bd75fe68c81a9799d);
#
#
#
#         marker_1e91552b8aa0dc7ac686086a74626bf2.bindPopup(popup_4396d00f18ba2d16e1a89ea3044166e6)
#         ;
#
#
#
#
#             var marker_037151a5157d79cc2eb395adc3b570de = L.marker(
#                 [45.590781, -73.589008],
#                 {}
#             ).addTo(map_57265822c32fc3202879fe0ba665c51f);
#
#
#         var popup_ddc52589a7d3295dc9f1e6848da9aace = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0609d7fbf0f1ad9c215d5542782e4d6 = $(`&lt;div id=&quot;html_f0609d7fbf0f1ad9c215d5542782e4d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#                 popup_ddc52589a7d3295dc9f1e6848da9aace.setContent(html_f0609d7fbf0f1ad9c215d5542782e4d6);
#
#
#
#         marker_037151a5157d79cc2eb395adc3b570de.bindPopup(popup_ddc52589a7d3295dc9f1e6848da9aace)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
d = {
    'id': [1, 2, 3, 4, 5, 6, 7, 8], 
    'longitude': [-73.589462, -73.590055, -73.590041, -73.589008, -73.605997, -73.606028, -73.606822, -73.606832],
    'latitude': [45.592012, 45.592189, 45.592181, 45.590781, 45.590096, 45.589438, 45.589075, 45.589065],
    'poly_id': [99, 99, 99, 99, 100, 100, 100, 100]
}
df = pd.DataFrame(data=d)

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf
# Out:
#    id  longitude   latitude  poly_id                    geometry
# 0   1 -73.589462  45.592012       99  POINT (-73.58946 45.59201)
# 1   2 -73.590055  45.592189       99  POINT (-73.59006 45.59219)
# 2   3 -73.590041  45.592181       99  POINT (-73.59004 45.59218)
# 3   4 -73.589008  45.590781       99  POINT (-73.58901 45.59078)
# 4   5 -73.605997  45.590096      100  POINT (-73.60600 45.59010)
# 5   6 -73.606028  45.589438      100  POINT (-73.60603 45.58944)
# 6   7 -73.606822  45.589075      100  POINT (-73.60682 45.58908)
# 7   8 -73.606832  45.589065      100  POINT (-73.60683 45.58906)

# %%
from scipy.spatial import cKDTree
import numpy as np

# Define a function to find the closest point for each group
def get_closest_points(group):
    # Create a KDTree from the geometry of the group
    tree = cKDTree(np.array(group.geometry.apply(lambda geom: [geom.x, geom.y])).tolist())
    
    # Query the tree for the closest points to each point in the group
    distances, indices = tree.query(np.array(group.geometry.apply(lambda geom: [geom.x, geom.y])).tolist(), k=2)

    # Get the closest point for each row in the group
    group['closest_point'] = group.geometry.iloc[indices[:, 1]].values
    
    return group

# Apply the function to each group defined by the 'poly_id' column
gdf = gdf.groupby('poly_id', group_keys=False).apply(get_closest_points).reset_index(drop=True)

# %%
gdf
# Out:
#    id  longitude   latitude  poly_id                    geometry  \
# 0   1 -73.589462  45.592012       99  POINT (-73.58946 45.59201)
# 1   2 -73.590055  45.592189       99  POINT (-73.59006 45.59219)
# 2   3 -73.590041  45.592181       99  POINT (-73.59004 45.59218)
# 3   4 -73.589008  45.590781       99  POINT (-73.58901 45.59078)
# 4   5 -73.605997  45.590096      100  POINT (-73.60600 45.59010)
# 5   6 -73.606028  45.589438      100  POINT (-73.60603 45.58944)
# 6   7 -73.606822  45.589075      100  POINT (-73.60682 45.58908)
# 7   8 -73.606832  45.589065      100  POINT (-73.60683 45.58906)
#
#                 closest_point
# 0  POINT (-73.59004 45.59218)
# 1  POINT (-73.59004 45.59218)
# 2  POINT (-73.59006 45.59219)
# 3  POINT (-73.58946 45.59201)
# 4  POINT (-73.60603 45.58944)
# 5  POINT (-73.60600 45.59010)
# 6  POINT (-73.60683 45.58906)
# 7  POINT (-73.60682 45.58908)

# %%
m2 = folium.Map(location=[45.5414195, -73.6303031], tiles="cartodbpositron", zoom_start=12)

# %%
for _, row in gdf.iterrows():
    lat = row.latitude
    lon = row.longitude
    folium.Marker(location=[lat, lon], popup=row["id"]).add_to(m2)

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67d07aac8a3badc15cebc0082ab45528 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67d07aac8a3badc15cebc0082ab45528&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67d07aac8a3badc15cebc0082ab45528 = L.map(
#                 &quot;map_67d07aac8a3badc15cebc0082ab45528&quot;,
#                 {
#                     center: [45.5414195, -73.6303031],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13693650d17c5408c0e0c2424a845428 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_67d07aac8a3badc15cebc0082ab45528);
#
#
#             var marker_16ac49dff765e17144bff17af7cb35dc = L.marker(
#                 [45.592012, -73.589462],
#                 {}
#             ).addTo(map_67d07aac8a3badc15cebc0082ab45528);
#
#
#         var popup_ad6a16eccfa7a1ea822d555a28da35a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9dcdd34fe8c4cbe37fb295f4078918ad = $(`&lt;div id=&quot;html_9dcdd34fe8c4cbe37fb295f4078918ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_ad6a16eccfa7a1ea822d555a28da35a6.setContent(html_9dcdd34fe8c4cbe37fb295f4078918ad);
#
#
#
#         marker_16ac49dff765e17144bff17af7cb35dc.bindPopup(popup_ad6a16eccfa7a1ea822d555a28da35a6)
#         ;
#
#
#
#
#             var marker_a7d84a34532b84b682539833b9c31e9d = L.marker(
#                 [45.592189, -73.590055],
#                 {}
#             ).addTo(map_67d07aac8a3badc15cebc0082ab45528);
#
#
#         var popup_e7ef1f1250065ae7443929565d898f12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2bb9fa9c88875af04b207754e21ea12e = $(`&lt;div id=&quot;html_2bb9fa9c88875af04b207754e21ea12e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_e7ef1f1250065ae7443929565d898f12.setContent(html_2bb9fa9c88875af04b207754e21ea12e);
#
#
#
#         marker_a7d84a34532b84b682539833b9c31e9d.bindPopup(popup_e7ef1f1250065ae7443929565d898f12)
#         ;
#
#
#
#
#             var marker_55d9eabfe1bf117a6740092557a2aa64 = L.marker(
#                 [45.592181, -73.590041],
#                 {}
#             ).addTo(map_67d07aac8a3badc15cebc0082ab45528);
#
#
#         var popup_2ae80b70985b668bc1ef9310ecc8b672 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_963f03092480ae5ef9feed48f666d34d = $(`&lt;div id=&quot;html_963f03092480ae5ef9feed48f666d34d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_2ae80b70985b668bc1ef9310ecc8b672.setContent(html_963f03092480ae5ef9feed48f666d34d);
#
#
#
#         marker_55d9eabfe1bf117a6740092557a2aa64.bindPopup(popup_2ae80b70985b668bc1ef9310ecc8b672)
#         ;
#
#
#
#
#             var marker_573c1edea52b075c6fef3cfdc8de2a94 = L.marker(
#                 [45.590781, -73.589008],
#                 {}
#             ).addTo(map_67d07aac8a3badc15cebc0082ab45528);
#
#
#         var popup_127ff66cb052ddace3bf7df5e1c5104f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3e5891ca4c1edf7cab256b53b0d2faf = $(`&lt;div id=&quot;html_a3e5891ca4c1edf7cab256b53b0d2faf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#                 popup_127ff66cb052ddace3bf7df5e1c5104f.setContent(html_a3e5891ca4c1edf7cab256b53b0d2faf);
#
#
#
#         marker_573c1edea52b075c6fef3cfdc8de2a94.bindPopup(popup_127ff66cb052ddace3bf7df5e1c5104f)
#         ;
#
#
#
#
#             var marker_e584d7f81fbe17b9265ea56095c61443 = L.marker(
#                 [45.590096, -73.605997],
#                 {}
#             ).addTo(map_67d07aac8a3badc15cebc0082ab45528);
#
#
#         var popup_d63a39ce900163593c1e0dc4247a3775 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff4cebb6590e1a1e265df07cbd3ab0c3 = $(`&lt;div id=&quot;html_ff4cebb6590e1a1e265df07cbd3ab0c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5&lt;/div&gt;`)[0];
#                 popup_d63a39ce900163593c1e0dc4247a3775.setContent(html_ff4cebb6590e1a1e265df07cbd3ab0c3);
#
#
#
#         marker_e584d7f81fbe17b9265ea56095c61443.bindPopup(popup_d63a39ce900163593c1e0dc4247a3775)
#         ;

# %%
result = result.geometry.set_crs('epsg:4326')

# %%
from geopy.distance import distance

def get_distance(row):
    point = row['geometry']
    closest_point = row['closest_point']
    return distance((point.y, point.x), (closest_point.y, closest_point.x)).meters

gdf.apply(get_distance, axis=1)
# Out:
# 0     48.928656
# 1      1.408537
# 2      1.408537
# 3    141.329531
# 4     73.172291
# 5     73.172291
# 6      1.358022
# 7      1.358022
# dtype: float64

# %%
def get_distance(row):
    return row.geometry.distance(row.closest_point)
    
gdf.apply(get_distance, axis=1)
# Out:
# 0    0.000603
# 1    0.000016
# 2    0.000016
# 3    0.001312
# 4    0.000659
# 5    0.000659
# 6    0.000014
# 7    0.000014
# dtype: float64
