# %%
import math
import numpy as np
import pandas as pd
import geopandas as gpd
from pandas import testing as tm
from ortools.sat.python import cp_model

# %%
df = pd.read_csv("fountains-distances-join-fountains-counts.csv")
df.head(4)
# Out:
#    id  nearest_rev  nearest_fountain  nearest_rvertes  nearest_pcyclable
# 0   1  2697.569104         48.907970      2512.295088         176.113692  \
# 1   2  2745.451551          1.408827      2541.866572         167.330400
# 2   3  2744.043719          1.408827      2540.756133         167.190902
# 3   4  2582.406191        141.348494      2371.053545          84.592035
#
#    nearest_murbain  nearest_iexterne           min_col    min_val  longitude
# 0      2529.702004                21  nearest_iexterne  21.446787 -73.589462  \
# 1      2495.967421                33  nearest_fountain   1.408827 -73.590055
# 2      2497.152536                32  nearest_fountain   1.408827 -73.590041
# 3      2670.529930                18  nearest_iexterne  18.837126 -73.589008
#
#     latitude  objectid  superficie  count
# 0  45.592012      5069    11.80462      5
# 1  45.592189      5069    11.80462      5
# 2  45.592181      5069    11.80462      5
# 3  45.590781      5069    11.80462      5

# %%
print(f"length < 1 (ha): {len(df[df['superficie'] < 1])}")
print(f"length 1-5 (ha): {len(df[(df['superficie'] >= 1) & (df['superficie'] < 5)])}")
print(f"length 5-20 (ha): {len(df[(df['superficie'] >= 5) & (df['superficie'] < 20)])}")
print(f"length 20-100 (ha): {len(df[(df['superficie'] >= 20) & (df['superficie'] < 100)])}")
print(f"length > 100 (ha): {len(df[df['superficie'] > 100])}")
# Out:
# length < 1 (ha): 230
# length 1-5 (ha): 299
# length 5-20 (ha): 197
# length 20-100 (ha): 66
# length > 100 (ha): 31

# %%
bins = [0, 1, 5, 20, 100, float('inf')]
labels = ['< 1', '1-5', '5-20', '20-100', '> 100']

# Ajout d'une colonne 'categorie' au DataFrame pour stocker la catégorie de chaque superficie
df['categorie'] = pd.cut(df['superficie'], bins=bins, labels=labels)

df.head(4)
# Out:
#    id  nearest_rev  nearest_fountain  nearest_rvertes  nearest_pcyclable
# 0   1  2697.569104         48.907970      2512.295088         176.113692  \
# 1   2  2745.451551          1.408827      2541.866572         167.330400
# 2   3  2744.043719          1.408827      2540.756133         167.190902
# 3   4  2582.406191        141.348494      2371.053545          84.592035
#
#    nearest_murbain  nearest_iexterne           min_col    min_val  longitude
# 0      2529.702004                21  nearest_iexterne  21.446787 -73.589462  \
# 1      2495.967421                33  nearest_fountain   1.408827 -73.590055
# 2      2497.152536                32  nearest_fountain   1.408827 -73.590041
# 3      2670.529930                18  nearest_iexterne  18.837126 -73.589008
#
#     latitude  objectid  superficie  count categorie
# 0  45.592012      5069    11.80462      5      5-20
# 1  45.592189      5069    11.80462      5      5-20
# 2  45.592181      5069    11.80462      5      5-20
# 3  45.590781      5069    11.80462      5      5-20

# %%
dictionnary = df.groupby("categorie").agg({"count": "max"}).to_dict()["count"]
df['max-fountain'] = df['categorie'].map(dictionnary)
df = df.rename(columns={"count": "nbr-fountain"})

df.head(4)
# Out:
#    id  nearest_rev  nearest_fountain  nearest_rvertes  nearest_pcyclable
# 0   1  2697.569104         48.907970      2512.295088         176.113692  \
# 1   2  2745.451551          1.408827      2541.866572         167.330400
# 2   3  2744.043719          1.408827      2540.756133         167.190902
# 3   4  2582.406191        141.348494      2371.053545          84.592035
#
#    nearest_murbain  nearest_iexterne           min_col    min_val  longitude
# 0      2529.702004                21  nearest_iexterne  21.446787 -73.589462  \
# 1      2495.967421                33  nearest_fountain   1.408827 -73.590055
# 2      2497.152536                32  nearest_fountain   1.408827 -73.590041
# 3      2670.529930                18  nearest_iexterne  18.837126 -73.589008
#
#     latitude  objectid  superficie  nbr-fountain categorie max-fountain
# 0  45.592012      5069    11.80462             5      5-20           11
# 1  45.592189      5069    11.80462             5      5-20           11
# 2  45.592181      5069    11.80462             5      5-20           11
# 3  45.590781      5069    11.80462             5      5-20           11

# %%
# Conversion en mètres carrés
df['superficie-metre'] = df['superficie'] * 10000

df.head(4)
# Out:
#    id  nearest_rev  nearest_fountain  nearest_rvertes  nearest_pcyclable
# 0   1  2697.569104         48.907970      2512.295088         176.113692  \
# 1   2  2745.451551          1.408827      2541.866572         167.330400
# 2   3  2744.043719          1.408827      2540.756133         167.190902
# 3   4  2582.406191        141.348494      2371.053545          84.592035
#
#    nearest_murbain  nearest_iexterne           min_col    min_val  longitude
# 0      2529.702004                21  nearest_iexterne  21.446787 -73.589462  \
# 1      2495.967421                33  nearest_fountain   1.408827 -73.590055
# 2      2497.152536                32  nearest_fountain   1.408827 -73.590041
# 3      2670.529930                18  nearest_iexterne  18.837126 -73.589008
#
#     latitude  objectid  superficie  nbr-fountain categorie max-fountain
# 0  45.592012      5069    11.80462             5      5-20           11  \
# 1  45.592189      5069    11.80462             5      5-20           11
# 2  45.592181      5069    11.80462             5      5-20           11
# 3  45.590781      5069    11.80462             5      5-20           11
#
#    superficie-metre
# 0     118046.202996
# 1     118046.202996
# 2     118046.202996
# 3     118046.202996

# %%
grouped = df.groupby('objectid')\
            .agg({
                'superficie-metre': 'first', 
                'nbr-fountain': 'first', 
                'max-fountain': 'first'})\
                    .reset_index()

print(grouped)
# Out:
#      objectid  superficie-metre  nbr-fountain max-fountain
# 0        3479      5.426809e+03             1            3
# 1        3482      4.711487e+04             4            5
# 2        3485      3.513201e+04             2            5
# 3        3494      4.019093e+04             2            5
# 4        3523      2.378247e+03             1            3
# ..        ...               ...           ...          ...
# 477      5659      1.775433e+05             2           11
# 478      5662      6.249648e+05             3           13
# 479      5679      1.278951e+04             2            5
# 480      5685      2.541568e+06             5           18
# 481      5691      1.546228e+05             1           11
#
# [482 rows x 4 columns]

# %%
grouped['max-fountain'] = grouped['max-fountain'].astype(int)

# Group by id_parc and get the max value of nbr_fountain for each group
max_fountains = grouped.groupby('objectid')['max-fountain'].max()

# Sum the maximum values
sum_max_fountains = max_fountains.sum()

# Print the result
print(sum_max_fountains)
# Out:
# 2525

# %%
# Create the CP-SAT model
model = cp_model.CpModel()

# Define the variables
fountains = [model.NewIntVar(0, grouped['max-fountain'][i], f'fountains{i}') for i in range(len(grouped))]

# Define the constraints
for i in range(len(grouped)):
    # Contrainte pour garantir qu'il y a au moins une fontaine par parc
    model.Add(fountains[i] >= 1)
    # Contrainte pour limiter le nombre de fontaines par parc
    model.Add(fountains[i] <= grouped['max-fountain'][i])
    # Contrainte pour limiter le nombre de fontaines en fonction de la superficie du parc
    model.Add(fountains[i] <= math.ceil(grouped['superficie-metre'][i] // 100))
    
# Contrainte pour limiter le nombre total de fontaines
model.Add(sum(fountains) <= sum_max_fountains)

# Define the objective function
model.Maximize(sum(fountains))

# Create the solver and solve the model
solver = cp_model.CpSolver()
status = solver.Solve(model)

# Print the solution
if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
    print('Solution trouvée avec un nombre total de fontaines de', solver.ObjectiveValue(), ':')
    for i in range(len(grouped)):
        print(f'Parc {grouped["objectid"][i]}: {solver.Value(fountains[i])} fontaines')
else:
    print('Aucune solution trouvée')
# Out:
# Solution trouvée avec un nombre total de fontaines de 2525.0 :
# Parc 3479: 3 fontaines
# Parc 3482: 5 fontaines
# Parc 3485: 5 fontaines
# Parc 3494: 5 fontaines
# Parc 3523: 3 fontaines
# Parc 3524: 11 fontaines
# Parc 3526: 5 fontaines
# Parc 3528: 5 fontaines
# Parc 3531: 3 fontaines
# Parc 3538: 3 fontaines
# Parc 3548: 5 fontaines
# Parc 3551: 5 fontaines
# Parc 3557: 5 fontaines
# Parc 3563: 5 fontaines
# Parc 3567: 5 fontaines
# Parc 3568: 3 fontaines
# Parc 3570: 3 fontaines
# Parc 3581: 5 fontaines
# Parc 3589: 11 fontaines
# Parc 3592: 5 fontaines
# Parc 3602: 3 fontaines
# Parc 3617: 3 fontaines
# Parc 3622: 3 fontaines
# Parc 3624: 3 fontaines
# Parc 3631: 11 fontaines
# Parc 3639: 5 fontaines
# Parc 3642: 11 fontaines
# Parc 3647: 5 fontaines
# Parc 3651: 11 fontaines
# Parc 3657: 3 fontaines
# Parc 3660: 5 fontaines
# Parc 3667: 5 fontaines
# Parc 3672: 5 fontaines
# Parc 3674: 5 fontaines
# Parc 3678: 11 fontaines
# Parc 3680: 5 fontaines
# Parc 3684: 3 fontaines
# Parc 3692: 5 fontaines
# Parc 3700: 18 fontaines
# Parc 3705: 3 fontaines
# Parc 3706: 5 fontaines
# Parc 3710: 3 fontaines
# Parc 3711: 5 fontaines
# Parc 3714: 3 fontaines
# Parc 3715: 11 fontaines
# Parc 3716: 5 fontaines
# Parc 3718: 5 fontaines
# Parc 3722: 11 fontaines
# Parc 3723: 3 fontaines
# Parc 3731: 3 fontaines
# Parc 3732: 11 fontaines
# Parc 3734: 5 fontaines
# Parc 3737: 5 fontaines
# Parc 3740: 11 fontaines
# Parc 3749: 3 fontaines
# Parc 3758: 3 fontaines
# Parc 3766: 3 fontaines
# Parc 3774: 5 fontaines
# Parc 3777: 5 fontaines
# Parc 3781: 5 fontaines
# Parc 3782: 5 fontaines
# Parc 3787: 5 fontaines
# Parc 3790: 5 fontaines
# Parc 3795: 5 fontaines
# Parc 3798: 5 fontaines
# Parc 3800: 3 fontaines
# Parc 3802: 5 fontaines
# Parc 3804: 3 fontaines
# Parc 3806: 5 fontaines
# Parc 3808: 11 fontaines
# Parc 3817: 11 fontaines
# Parc 3827: 5 fontaines
# Parc 3828: 5 fontaines

#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains286"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains287"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains288"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains289"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains290"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains291"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains292"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains293"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains294"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains295"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains296"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains297"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains298"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains299"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains300"
#   domain: 0
#   domain: 13
# }
# variables {
#   name: "fountains301"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains302"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains303"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains304"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains305"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains306"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains307"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains308"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains309"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains310"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains311"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains312"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains313"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains314"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains315"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains316"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains317"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains318"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains319"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains320"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains321"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains322"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains323"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains324"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains325"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains326"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains327"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains328"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains329"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains330"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains331"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains332"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains333"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains334"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains335"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains336"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains337"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains338"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains339"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains340"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains341"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains342"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains343"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains344"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains345"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains346"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains347"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains348"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains349"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains350"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains351"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains352"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains353"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains354"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains355"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains356"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains357"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains358"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains359"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains360"
#   domain: 0
#   domain: 13
# }
# variables {
#   name: "fountains361"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains362"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains363"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains364"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains365"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains366"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains367"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains368"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains369"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains370"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains371"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains372"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains373"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains374"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains375"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains376"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains377"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains378"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains379"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains380"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains381"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains382"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains383"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains384"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains385"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains386"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains387"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains388"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains389"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains390"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains391"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains392"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains393"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains394"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains395"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains396"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains397"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains398"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains399"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains400"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains401"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains402"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains403"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains404"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains405"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains406"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains407"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains408"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains409"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains410"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains411"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains412"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains413"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains414"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains415"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains416"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains417"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains418"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains419"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains420"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains421"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains422"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains423"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains424"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains425"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains426"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains427"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains428"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains429"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains430"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains431"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains432"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains433"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains434"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains435"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains436"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains437"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains438"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains439"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains440"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains441"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains442"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains443"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains444"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains445"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains446"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains447"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains448"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains449"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains450"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains451"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains452"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains453"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains454"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains455"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains456"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains457"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains458"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains459"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains460"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains461"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains462"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains463"
#   domain: 0
#   domain: 13
# }
# variables {
#   name: "fountains464"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains465"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains466"
#   domain: 0
#   domain: 13
# }
# variables {
#   name: "fountains467"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains468"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains469"
#   domain: 0
#   domain: 13
# }
# variables {
#   name: "fountains470"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains471"
#   domain: 0
#   domain: 3
# }
# variables {
#   name: "fountains472"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains473"
#   domain: 0
#   domain: 13
# }
# variables {
#   name: "fountains474"
#   domain: 0
#   domain: 18
# }
# variables {
#   name: "fountains475"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains476"
#   domain: 0
#   domain: 18
# }
# variables {
#   name: "fountains477"
#   domain: 0
#   domain: 11
# }
# variables {
#   name: "fountains478"
#   domain: 0
#   domain: 13
# }
# variables {
#   name: "fountains479"
#   domain: 0
#   domain: 5
# }
# variables {
#   name: "fountains480"
#   domain: 0
#   domain: 18
# }
# variables {
#   name: "fountains481"
#   domain: 0
#   domain: 11
# }
# constraints {
#   linear {
#     vars: 0
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 0
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 0
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 54
#   }
# }
# constraints {
#   linear {
#     vars: 1
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 471
#   }
# }
# constraints {
#   linear {
#     vars: 2
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 2
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 2
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 351
#   }
# }
# constraints {
#   linear {
#     vars: 3
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 3
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 3
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 401
#   }
# }
# constraints {
#   linear {
#     vars: 4
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 4
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 4
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 23
#   }
# }
# constraints {
#   linear {
#     vars: 5
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 5
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 5
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1083
#   }
# }
# constraints {
#   linear {
#     vars: 6
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 6
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 6
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 108
#   }
# }
# constraints {
#   linear {
#     vars: 7
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 7
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 7
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 183
#   }
# }
# constraints {
#   linear {
#     vars: 8
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 8
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 8
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 87
#   }
# }
# constraints {
#   linear {
#     vars: 9
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 9
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 9
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 81
#   }
# }
# constraints {
#   linear {
#     vars: 10
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 10
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 10
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 180
#   }
# }
# constraints {
#   linear {
#     vars: 11
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 11
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 11
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 101
#   }
# }
# constraints {
#   linear {
#     vars: 12
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 12
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 12
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 175
#   }
# }
# constraints {
#   linear {
#     vars: 13
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 13
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 13
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 127
#   }
# }
# constraints {
#   linear {
#     vars: 14
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 14
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 14
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 409
#   }
# }
# constraints {
#   linear {
#     vars: 15
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 15
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 15
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 14
#   }
# }
# constraints {
#   linear {
#     vars: 16
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 16
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 16
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 43
#   }
# }
# constraints {
#   linear {
#     vars: 17
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 17
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 17
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 103
#   }
# }
# constraints {
#   linear {
#     vars: 18
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 18
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 18
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 821
#   }
# }
# constraints {
#   linear {
#     vars: 19
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 19
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 19
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 253
#   }
# }
# constraints {
#   linear {
#     vars: 20
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 20
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 20
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 4
#   }
# }
# constraints {
#   linear {
#     vars: 21
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 21
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 21
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 91
#   }
# }
# constraints {
#   linear {
#     vars: 22
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 22
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 22
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 19
#   }
# }
# constraints {
#   linear {
#     vars: 23
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 23
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 23
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 21
#   }
# }
# constraints {
#   linear {
#     vars: 24
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 24
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 24
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 921
#   }
# }
# constraints {
#   linear {
#     vars: 25
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 25
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 25
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 132
#   }
# }
# constraints {
#   linear {
#     vars: 26
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 26
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 26
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1521
#   }
# }
# constraints {
#   linear {
#     vars: 27
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 27
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 27
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 224
#   }
# }
# constraints {
#   linear {
#     vars: 28
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 28
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 28
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1429
#   }
# }
# constraints {
#   linear {
#     vars: 29
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 29
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 29
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 84
#   }
# }
# constraints {
#   linear {
#     vars: 30
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 30
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 30
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 308
#   }
# }
# constraints {
#   linear {
#     vars: 31
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 31
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 31
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 234
#   }
# }
# constraints {
#   linear {
#     vars: 32
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 32
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 32
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 357
#   }
# }
# constraints {
#   linear {
#     vars: 33
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 33
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 33
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 151
#   }
# }
# constraints {
#   linear {
#     vars: 34
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 34
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 34
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 729
#   }
# }
# constraints {
#   linear {
#     vars: 35
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 35
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 35
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 337
#   }
# }
# constraints {
#   linear {
#     vars: 36
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 36
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 36
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 51
#   }
# }
# constraints {
#   linear {
#     vars: 37
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 37
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 37
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 330
#   }
# }
# constraints {
#   linear {
#     vars: 38
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 38
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 18
#   }
# }
# constraints {
#   linear {
#     vars: 38
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 15291
#   }
# }
# constraints {
#   linear {
#     vars: 39
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 39
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 39
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 36
#   }
# }
# constraints {
#   linear {
#     vars: 40
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 40
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 40
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 326
#   }
# }
# constraints {
#   linear {
#     vars: 41
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 41
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 41
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 76
#   }
# }
# constraints {
#   linear {
#     vars: 42
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 42
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 42
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 165
#   }
# }
# constraints {
#   linear {
#     vars: 43
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 43
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 43
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 63
#   }
# }
# constraints {
#   linear {
#     vars: 44
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 44
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 44
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 504
#   }
# }
# constraints {
#   linear {
#     vars: 45
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 45
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 45
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 244
#   }
# }
# constraints {
#   linear {
#     vars: 46
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 46
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 46
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 121
#   }
# }
# constraints {
#   linear {
#     vars: 47
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 47
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 47
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 672
#   }
# }
# constraints {
#   linear {
#     vars: 48
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 48
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 48
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 61
#   }
# }
# constraints {
#   linear {
#     vars: 49
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 49
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 49
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 86
#   }
# }
# constraints {
#   linear {
#     vars: 50
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 50
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 50
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 584
#   }
# }
# constraints {
#   linear {
#     vars: 51
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 51
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 51
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 146
#   }
# }
# constraints {
#   linear {
#     vars: 52
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 52
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 52
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 373
#   }
# }
# constraints {
#   linear {
#     vars: 53
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 53
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 11
#   }
# }
# constraints {
#   linear {
#     vars: 53
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1084
#   }
# }
# constraints {
#   linear {
#     vars: 54
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 54
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 54
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 73
#   }
# }
# constraints {
#   linear {
#     vars: 55
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 55
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 55
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 28
#   }
# }
# constraints {
#   linear {
#     vars: 56
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 56
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 3
#   }
# }
# constraints {
#   linear {
#     vars: 56
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 94
#   }
# }
# constraints {
#   linear {
#     vars: 57
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 57
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 57
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 243
#   }
# }
# constraints {
#   linear {
#     vars: 58
#     coeffs: 1
#     domain: 1
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   linear {
#     vars: 58
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 5
#   }
# }
# constraints {
#   linear {
#     vars: 58
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 180
#   }
# }
# constraints {
# ...
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 2525
#   }
# }
# objective {
#   vars: -482
#   vars: -481
#   vars: -480
#   vars: -479
#   vars: -478
#   vars: -477
#   vars: -476
#   vars: -475
#   vars: -474
#   vars: -473
#   vars: -472
#   vars: -471
#   vars: -470
#   vars: -469
#   vars: -468
#   vars: -467
#   vars: -466
#   vars: -465
#   vars: -464
#   vars: -463
#   vars: -462
#   vars: -461
#   vars: -460
#   vars: -459
#   vars: -458
#   vars: -457
#   vars: -456
#   vars: -455
#   vars: -454
#   vars: -453
#   vars: -452
#   vars: -451
#   vars: -450
#   vars: -449
#   vars: -448
#   vars: -447
#   vars: -446
#   vars: -445
#   vars: -444
#   vars: -443
#   vars: -442
#   vars: -441
#   vars: -440
#   vars: -439
#   vars: -438
#   vars: -437
#   vars: -436
#   vars: -435
#   vars: -434
#   vars: -433
#   vars: -432
#   vars: -431
#   vars: -430
#   vars: -429
#   vars: -428
#   vars: -427
#   vars: -426
#   vars: -425
#   vars: -424
#   vars: -423
#   vars: -422
#   vars: -421
#   vars: -420
#   vars: -419
#   vars: -418
#   vars: -417
#   vars: -416
#   vars: -415
#   vars: -414
#   vars: -413
#   vars: -412
#   vars: -411
#   vars: -410
#   vars: -409
#   vars: -408
#   vars: -407
#   vars: -406
#   vars: -405
#   vars: -404
#   vars: -403
#   vars: -402
#   vars: -401
#   vars: -400
#   vars: -399
#   vars: -398
#   vars: -397
#   vars: -396
#   vars: -395
#   vars: -394
#   vars: -393
#   vars: -392
#   vars: -391
#   vars: -390
#   vars: -389
#   vars: -388
#   vars: -387
#   vars: -386
#   vars: -385
#   vars: -384
#   vars: -383
#   vars: -382
#   vars: -381
#   vars: -380
#   vars: -379
#   vars: -378
#   vars: -377
#   vars: -376
#   vars: -375
#   vars: -374
#   vars: -373
#   vars: -372
#   vars: -371
#   vars: -370
#   vars: -369
#   vars: -368
#   vars: -367
#   vars: -366
#   vars: -365
#   vars: -364
#   vars: -363
#   vars: -362
#   vars: -361
#   vars: -360
#   vars: -359
#   vars: -358
#   vars: -357
#   vars: -356
#   vars: -355
#   vars: -354
#   vars: -353
#   vars: -352
#   vars: -351
#   vars: -350
#   vars: -349
#   vars: -348
#   vars: -347
#   vars: -346
#   vars: -345
#   vars: -344
#   vars: -343
#   vars: -342
#   vars: -341
#   vars: -340
#   vars: -339
#   vars: -338
#   vars: -337
#   vars: -336
#   vars: -335
#   vars: -334
#   vars: -333
#   vars: -332
#   vars: -331
#   vars: -330
#   vars: -329
#   vars: -328
#   vars: -327
#   vars: -326
#   vars: -325
#   vars: -324
#   vars: -323
#   vars: -322
#   vars: -321
#   vars: -320
#   vars: -319
#   vars: -318
#   vars: -317
#   vars: -316
#   vars: -315
#   vars: -314
#   vars: -313
#   vars: -312
#   vars: -311
#   vars: -310
#   vars: -309
#   vars: -308
#   vars: -307
#   vars: -306
#   vars: -305
#   vars: -304
#   vars: -303
#   vars: -302
#   vars: -301
#   vars: -300
#   vars: -299
#   vars: -298
#   vars: -297
#   vars: -296
#   vars: -295
#   vars: -294
#   vars: -293
#   vars: -292
#   vars: -291
#   vars: -290
#   vars: -289
#   vars: -288
#   vars: -287
#   vars: -286
#   vars: -285
#   vars: -284
#   vars: -283
#   vars: -282
#   vars: -281
#   vars: -280
#   vars: -279
#   vars: -278
#   vars: -277
#   vars: -276
#   vars: -275
#   vars: -274
#   vars: -273
#   vars: -272
#   vars: -271
#   vars: -270
#   vars: -269
#   vars: -268
#   vars: -267
#   vars: -266
#   vars: -265
#   vars: -264
#   vars: -263
#   vars: -262
#   vars: -261
#   vars: -260
#   vars: -259
#   vars: -258
#   vars: -257
#   vars: -256
#   vars: -255
#   vars: -254
#   vars: -253
#   vars: -252
#   vars: -251
#   vars: -250
#   vars: -249
#   vars: -248
#   vars: -247
#   vars: -246
#   vars: -245
#   vars: -244
#   vars: -243
#   vars: -242
#   vars: -241
#   vars: -240
#   vars: -239
#   vars: -238
#   vars: -237
#   vars: -236
#   vars: -235
#   vars: -234
#   vars: -233
#   vars: -232
#   vars: -231
#   vars: -230
#   vars: -229
#   vars: -228
#   vars: -227
#   vars: -226
#   vars: -225
#   vars: -224
#   vars: -223
#   vars: -222
#   vars: -221
#   vars: -220
#   vars: -219
#   vars: -218
#   vars: -217
#   vars: -216
#   vars: -215
#   vars: -214
#   vars: -213
#   vars: -212
#   vars: -211
#   vars: -210
#   vars: -209
#   vars: -208
#   vars: -207
#   vars: -206
#   vars: -205
#   vars: -204
#   vars: -203
#   vars: -202
#   vars: -201
#   vars: -200
#   vars: -199
#   vars: -198
#   vars: -197
#   vars: -196
#   vars: -195
#   vars: -194
#   vars: -193
#   vars: -192
#   vars: -191
#   vars: -190
#   vars: -189
#   vars: -188
#   vars: -187
#   vars: -186
#   vars: -185
#   vars: -184
#   vars: -183
#   vars: -182
#   vars: -181
#   vars: -180
#   vars: -179
#   vars: -178
#   vars: -177
#   vars: -176
#   vars: -175
#   vars: -174
#   vars: -173
#   vars: -172
#   vars: -171
#   vars: -170
#   vars: -169
#   vars: -168
#   vars: -167
#   vars: -166
#   vars: -165
#   vars: -164
#   vars: -163
#   vars: -162
#   vars: -161
#   vars: -160
#   vars: -159
#   vars: -158
#   vars: -157
#   vars: -156
#   vars: -155
#   vars: -154
#   vars: -153
#   vars: -152
#   vars: -151
#   vars: -150
#   vars: -149
#   vars: -148
#   vars: -147
#   vars: -146
#   vars: -145
#   vars: -144
#   vars: -143
#   vars: -142
#   vars: -141
#   vars: -140
#   vars: -139
#   vars: -138
#   vars: -137
#   vars: -136
#   vars: -135
#   vars: -134
#   vars: -133
#   vars: -132
#   vars: -131
#   vars: -130
#   vars: -129
#   vars: -128
#   vars: -127
#   vars: -126
#   vars: -125
#   vars: -124
#   vars: -123
#   vars: -122
#   vars: -121
#   vars: -120
#   vars: -119
#   vars: -118
#   vars: -117
#   vars: -116
#   vars: -115
#   vars: -114
#   vars: -113
#   vars: -112
#   vars: -111
#   vars: -110
#   vars: -109
#   vars: -108
#   vars: -107
#   vars: -106
#   vars: -105
#   vars: -104
#   vars: -103
#   vars: -102
#   vars: -101
#   vars: -100
#   vars: -99
#   vars: -98
#   vars: -97
#   vars: -96
#   vars: -95
#   vars: -94
#   vars: -93
#   vars: -92
#   vars: -91
#   vars: -90
#   vars: -89
#   vars: -88
#   vars: -87
#   vars: -86
#   vars: -85
#   vars: -84
#   vars: -83
#   vars: -82
#   vars: -81
#   vars: -80
#   vars: -79
#   vars: -78
#   vars: -77
#   vars: -76
#   vars: -75
#   vars: -74
#   vars: -73
#   vars: -72
#   vars: -71
#   vars: -70
#   vars: -69
#   vars: -68
#   vars: -67
#   vars: -66
#   vars: -65
#   vars: -64
#   vars: -63
#   vars: -62
#   vars: -61
#   vars: -60
#   vars: -59
#   vars: -58
#   vars: -57
#   vars: -56
#   vars: -55
#   vars: -54
#   vars: -53
#   vars: -52
#   vars: -51
#   vars: -50
#   vars: -49
#   vars: -48
#   vars: -47
#   vars: -46
#   vars: -45
#   vars: -44
#   vars: -43
#   vars: -42
#   vars: -41
#   vars: -40
#   vars: -39
#   vars: -38
#   vars: -37
#   vars: -36
#   vars: -35
#   vars: -34
#   vars: -33
#   vars: -32
#   vars: -31
#   vars: -30
#   vars: -29
#   vars: -28
#   vars: -27
#   vars: -26
#   vars: -25
#   vars: -24
#   vars: -23
#   vars: -22
#   vars: -21
#   vars: -20
#   vars: -19
#   vars: -18
#   vars: -17
#   vars: -16
#   vars: -15
#   vars: -14
#   vars: -13
#   vars: -12
#   vars: -11
#   vars: -10
#   vars: -9
#   vars: -8
#   vars: -7
#   vars: -6
#   vars: -5
#   vars: -4
#   vars: -3
#   vars: -2
#   vars: -1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   scaling_factor: -1
# }

# %%
import re

# the input string
input_str = """
variables {
  name: "fountains480"
  domain: 0
  domain: 18
}
variables {
  name: "fountains481"
  domain: 0
  domain: 11
}
constraints {
  linear {
    vars: 0
    coeffs: 1
    domain: 1
    domain: 9223372036854775807
  }
}
constraints {
  linear {
    vars: 0
    coeffs: 1
    domain: -9223372036854775808
    domain: 3
  }
}
"""

# initialize an empty dictionary to store the extracted information
result_dict = {
    "variables": [],
    "constraints": []
}

# use regex to extract the necessary information and store it in the dictionary
variable_regex = re.compile(r'variables\s*{\s*name:\s*"(.+)"\s*domain:\s*(\d+)\s*domain:\s*(\d+)\s*}\s*')
constraint_regex = re.compile(r'constraints\s*{\s*linear\s*{\s*vars:\s*(\d+)\s*coeffs:\s*(\d+)\s*domain:\s*(.+)\s*domain:\s*(.+)\s*}\s*}\s*')

for match in variable_regex.finditer(input_str):
    result_dict["variables"].append({
        "name": match.group(1),
        "domain": [int(match.group(2)), int(match.group(3))]
    })

for match in constraint_regex.finditer(input_str):
    result_dict["constraints"].append({
        "vars": int(match.group(1)),
        "coeffs": int(match.group(2)),
        "domain": [int(match.group(3)), int(match.group(4))]
    })

print(result_dict)
# Out:
# {'variables': [{'name': 'fountains480', 'domain': [0, 18]}, {'name': 'fountains481', 'domain': [0, 11]}], 'constraints': [{'vars': 0, 'coeffs': 1, 'domain': [1, 9223372036854775807]}, {'vars': 0, 'coeffs': 1, 'domain': [-9223372036854775808, 3]}]}

# %%
class SolutionPrinter(cp_model.CpSolverSolutionCallback):
        
    def __init__(self, fountains, results):
        """Fonction de callback qui stocke les solutions trouvées"""
        cp_model.CpSolverSolutionCallback.__init__(self)
        self.fountains = fountains
        self.results = results
        self.solution_count = 0
    
    def OnSolutionCallback(self):
        """Stocke la solution trouvée dans le dictionnaire results"""
        self.solution_count += 1
        for i, f in enumerate(self.fountains):
            self.results[f'Parc {i+1}'] = self.Value(f)

# %%
# Create a list of dictionaries to store the solution data
solution_data = []
for i in range(len(grouped)):
    solution_data.append({'objectid': grouped['objectid'][i], 'nbr-fountain': solver.Value(fountains[i])})

# Create a DataFrame from the solution data
solution_df = pd.DataFrame(solution_data)

# Export the DataFrame to a CSV file
# solution_df.to_csv('solution.csv', index=False)

# %%
df_ortools = solution_df.copy()
df_ortools.head(10)
# Out:
#    objectid  nbr-fountain
# 0      3479             3
# 1      3482             5
# 2      3485             5
# 3      3494             5
# 4      3523             3
# 5      3524            11
# 6      3526             5
# 7      3528             5
# 8      3531             3
# 9      3538             3

# %%
columns = ["objectid", "nbr-fountain"]
df_origine = grouped.copy()[columns]
df_origine.head(10)
# Out:
#    objectid  nbr-fountain
# 0      3479             1
# 1      3482             4
# 2      3485             2
# 3      3494             2
# 4      3523             1
# 5      3524             1
# 6      3526             1
# 7      3528             2
# 8      3531             1
# 9      3538             1

# %%
# df_origine = grouped.copy()
# df_origine = df_origine.rename(columns={"count": "nbr_fountain"})
# df_origine = df_origine.astype({"objectid": "int64", "nbr_fountain": "int64", "max-fountains": "int64"})

# df_origine.head(4)

# %%
# df_ortools = df_ortools.rename(columns={"max-fountains": "nbr_fountain"})
# df_ortools = df_ortools.astype({"objectid": "int64", "nbr_fountain": "int64", "superficie-metre": "float64"})

# df_ortools.head(4)

# %%
# # Joindre les deux dataframes sur la colonne 'id_parc'
# df_compare = pd.merge(df_origine, df_ortools, on='objectid', suffixes=('_origine', '_ortools'))

# # Ajouter une colonne 'compare' pour indiquer si le nombre de fontaines généré par ortools est supérieur, égal ou inférieur au nombre d'origine
# df_compare['compare'] = np.where(df_compare['nbr_fountain_ortools'] > df_compare['nbr_fountain_origine'], 'supérieur', np.where(df_compare['nbr_fountain_ortools'] == df_compare['nbr_fountain_origine'], 'égal', 'inférieur'))

# # Afficher le dataframe de comparaison
# df_compare.head(10)
