# %%
import os
import folium
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon

from utils import *

# %% [markdown]
# ### Fountain

# %%
fountains = pd.read_csv(os.getenv("fountains"))
fountains.columns = fountains.columns.str.lower()

# %%
fountains = gpd.GeoDataFrame(fountains, geometry=gpd.points_from_xy(fountains.longitude, fountains.latitude))

# %%
print(fountains.crs)
# Out:
# None

# %%
fountains = fountains.set_crs('epsg:4326')

# %%
print(fountains.crs)
# Out:
# epsg:4326

# %% [markdown]
# ### calcul the distance between fountain and closest one

# %%
# fountains_utm = fountains.to_crs(epsg=32188)

# %%
from scipy.spatial import cKDTree

# Create a KDTree from the geometry of the GeoDataFrame
tree = cKDTree(np.array(fountains.geometry.apply(lambda geom: [geom.x, geom.y])).tolist())

# Query the tree for the closest points to each point in the GeoDataFrame
distances, indices = tree.query(np.array(fountains.geometry.apply(lambda geom: [geom.x, geom.y])).tolist(), k=2)

# Get the closest point for each row
fountains['closest_point'] = fountains.geometry.iloc[indices[:, 1]].values

# %%
from geopy.distance import distance

def get_distance(row):
    point = row['geometry']
    closest_point = row['closest_point']
    return distance((point.y, point.x), (closest_point.y, closest_point.x)).meters

# %%
fountains["closest_fountain"] = fountains.apply(get_distance, axis=1)

# %%
m = folium.Map(location=[45.5414195, -73.6303031], tiles="cartodbpositron", zoom_start=12)

# %%
part = fountains[fountains.nom_parc_lieu.str.contains("Royal", na=False)]
for _, row in part.iterrows():
    lat = row.latitude
    lon = row.longitude
    folium.Marker(location=[lat, lon], popup=row[["id", "longitude", "latitude"]]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_355faa9270b05d512053dba92a066688 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_355faa9270b05d512053dba92a066688&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_355faa9270b05d512053dba92a066688 = L.map(
#                 &quot;map_355faa9270b05d512053dba92a066688&quot;,
#                 {
#                     center: [45.5414195, -73.6303031],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2eee6abdc70255791b7f4f2bd269df9 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_355faa9270b05d512053dba92a066688);
#
#
#             var marker_91580723bf2e9fe93eb13984faa3a720 = L.marker(
#                 [45.5045921771973, -73.5820034636704],
#                 {}
#             ).addTo(map_355faa9270b05d512053dba92a066688);
#
#
#         var popup_2393bb952c76a577349d632398ea8cd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b21b451e7cf371f2221234dacfed3f0 = $(`&lt;div id=&quot;html_7b21b451e7cf371f2221234dacfed3f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 631 longitude   -73.582003 latitude     45.504592 Name: 620, dtype: object&lt;/div&gt;`)[0];
#                 popup_2393bb952c76a577349d632398ea8cd9.setContent(html_7b21b451e7cf371f2221234dacfed3f0);
#
#
#
#         marker_91580723bf2e9fe93eb13984faa3a720.bindPopup(popup_2393bb952c76a577349d632398ea8cd9)
#         ;
#
#
#
#
#             var marker_a500e7b7339a0a04169801a647077aeb = L.marker(
#                 [45.5034201653086, -73.5874187076881],
#                 {}
#             ).addTo(map_355faa9270b05d512053dba92a066688);
#
#
#         var popup_31306f75db46212065addb25c881483e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a193cca9f236b1d0ce9f0c354f35f932 = $(`&lt;div id=&quot;html_a193cca9f236b1d0ce9f0c354f35f932&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 841 longitude   -73.587419 latitude      45.50342 Name: 827, dtype: object&lt;/div&gt;`)[0];
#                 popup_31306f75db46212065addb25c881483e.setContent(html_a193cca9f236b1d0ce9f0c354f35f932);
#
#
#
#         marker_a500e7b7339a0a04169801a647077aeb.bindPopup(popup_31306f75db46212065addb25c881483e)
#         ;
#
#
#
#
#             var marker_4060742d1f9e467c9e144f036c2777ad = L.marker(
#                 [45.5037201625941, -73.586842424373],
#                 {}
#             ).addTo(map_355faa9270b05d512053dba92a066688);
#
#
#         var popup_e6b79774e20b92ba5cf64f689715ee3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96d6649b121071652bdded1ac971869f = $(`&lt;div id=&quot;html_96d6649b121071652bdded1ac971869f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 842 longitude   -73.586842 latitude      45.50372 Name: 828, dtype: object&lt;/div&gt;`)[0];
#                 popup_e6b79774e20b92ba5cf64f689715ee3a.setContent(html_96d6649b121071652bdded1ac971869f);
#
#
#
#         marker_4060742d1f9e467c9e144f036c2777ad.bindPopup(popup_e6b79774e20b92ba5cf64f689715ee3a)
#         ;
#
#
#
#
#             var marker_a6acc5d1b6cb42b6b39192396205d5f9 = L.marker(
#                 [45.5020969236876, -73.5870945759392],
#                 {}
#             ).addTo(map_355faa9270b05d512053dba92a066688);
#
#
#         var popup_f850f184d33c947879d5533b6e9fa0e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1800a4c4ebc806ab6782c6164d0005e = $(`&lt;div id=&quot;html_b1800a4c4ebc806ab6782c6164d0005e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 843 longitude   -73.587095 latitude     45.502097 Name: 829, dtype: object&lt;/div&gt;`)[0];
#                 popup_f850f184d33c947879d5533b6e9fa0e3.setContent(html_b1800a4c4ebc806ab6782c6164d0005e);
#
#
#
#         marker_a6acc5d1b6cb42b6b39192396205d5f9.bindPopup(popup_f850f184d33c947879d5533b6e9fa0e3)
#         ;
#
#
#
#
#             var marker_dd72f330d35a536e60b41fabacd17f35 = L.marker(
#                 [45.5027301319067, -73.5917081726892],
#                 {}
#             ).addTo(map_355faa9270b05d512053dba92a066688);
#
#
#         var popup_553a5377c8e4fe54adffff6600e729c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 va

# %%
# https://stackoverflow.com/questions/19412462/getting-distance-between-two-points-based-on-latitude-longitude

from geopy.distance import geodesic


origin = (45.504592, -73.582003)  # (latitude, longitude) don't confuse
dist = (45.505103, -73.583063)

print(geodesic(origin, dist).meters)  # 23576.805481751613
print(geodesic(origin, dist).kilometers)  # 23.576805481751613
print(geodesic(origin, dist).miles)  # 14.64994773134371
# Out:
# 100.43916649131438
# 0.10043916649131439
# 0.0624100046300321

# %%
df = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'long': [-73.582003, -73.587419, -73.586842, -73.587095],
    'lat': [45.504592, 45.503420, 45.503720, 45.502097]})

df
# Out:
#    id       long        lat
# 0   1 -73.582003  45.504592
# 1   2 -73.587419  45.503420
# 2   3 -73.586842  45.503720
# 3   4 -73.587095  45.502097

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.long, df.lat))

# %%
print(gdf.crs)
# Out:
# None

# %%
gdf = gdf.set_crs('epsg:32188')

# %%
print(gdf.crs)
# Out:
# epsg:32188

# %%
gdf.sjoin_nearest(gdf.copy(), distance_col="distance")
# Out:
#    id_left  long_left   lat_left                geometry  index_right
# 0        1 -73.582003  45.504592  POINT (-73.582 45.505)            0  \
# 1        2 -73.587419  45.503420  POINT (-73.587 45.503)            1
# 2        3 -73.586842  45.503720  POINT (-73.587 45.504)            2
# 3        4 -73.587095  45.502097  POINT (-73.587 45.502)            3
#
#    id_right  long_right  lat_right  distance
# 0         1  -73.582003  45.504592       0.0
# 1         2  -73.587419  45.503420       0.0
# 2         3  -73.586842  45.503720       0.0
# 3         4  -73.587095  45.502097       0.0

# %%
m = folium.Map(location=[45.5414195, -73.6303031], tiles="cartodbpositron", zoom_start=12)

# %%
for _, row in gdf.iterrows():
    lat = row.lat
    lon = row.long
    folium.Marker(location=[lat, lon], popup=row["id"]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0efc439fd634cbd108efc6854844ab46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0efc439fd634cbd108efc6854844ab46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0efc439fd634cbd108efc6854844ab46 = L.map(
#                 &quot;map_0efc439fd634cbd108efc6854844ab46&quot;,
#                 {
#                     center: [45.5414195, -73.6303031],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6628be34b15838355f422d4f9a27ccd0 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0efc439fd634cbd108efc6854844ab46);
#
#
#             var marker_214eb042e9b5ea0d9edfb5d403a25def = L.marker(
#                 [45.504592, -73.582003],
#                 {}
#             ).addTo(map_0efc439fd634cbd108efc6854844ab46);
#
#
#         var popup_2d70eb48154359bcdfc8f34645c35184 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1569279ffdddd3de183a4c460d5b9ae3 = $(`&lt;div id=&quot;html_1569279ffdddd3de183a4c460d5b9ae3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_2d70eb48154359bcdfc8f34645c35184.setContent(html_1569279ffdddd3de183a4c460d5b9ae3);
#
#
#
#         marker_214eb042e9b5ea0d9edfb5d403a25def.bindPopup(popup_2d70eb48154359bcdfc8f34645c35184)
#         ;
#
#
#
#
#             var marker_79e6e79421f41a53bff9c21e226a2f19 = L.marker(
#                 [45.50342, -73.587419],
#                 {}
#             ).addTo(map_0efc439fd634cbd108efc6854844ab46);
#
#
#         var popup_8be549d8d228f7a62b159b13b8fb423c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2858cc22f6aa772be6bc9b8ff37d1e72 = $(`&lt;div id=&quot;html_2858cc22f6aa772be6bc9b8ff37d1e72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_8be549d8d228f7a62b159b13b8fb423c.setContent(html_2858cc22f6aa772be6bc9b8ff37d1e72);
#
#
#
#         marker_79e6e79421f41a53bff9c21e226a2f19.bindPopup(popup_8be549d8d228f7a62b159b13b8fb423c)
#         ;
#
#
#
#
#             var marker_bb0aa450b34c1d19a03e1296562f0c20 = L.marker(
#                 [45.50372, -73.586842],
#                 {}
#             ).addTo(map_0efc439fd634cbd108efc6854844ab46);
#
#
#         var popup_fff8656ebff05acdba834d1aa1bcebc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8dbf856cbf10a3b29602fb59905c7ca = $(`&lt;div id=&quot;html_a8dbf856cbf10a3b29602fb59905c7ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_fff8656ebff05acdba834d1aa1bcebc8.setContent(html_a8dbf856cbf10a3b29602fb59905c7ca);
#
#
#
#         marker_bb0aa450b34c1d19a03e1296562f0c20.bindPopup(popup_fff8656ebff05acdba834d1aa1bcebc8)
#         ;
#
#
#
#
#             var marker_3c3d481a6fedc546ec3cd1ce5de21236 = L.marker(
#                 [45.502097, -73.587095],
#                 {}
#             ).addTo(map_0efc439fd634cbd108efc6854844ab46);
#
#
#         var popup_1073db59a87adca7a22a696cc5e6d6f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c9b99592776f61741ad98dc67c5b18d = $(`&lt;div id=&quot;html_7c9b99592776f61741ad98dc67c5b18d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#                 popup_1073db59a87adca7a22a696cc5e6d6f6.setContent(html_7c9b99592776f61741ad98dc67c5b18d);
#
#
#
#         marker_3c3d481a6fedc546ec3cd1ce5de21236.bindPopup(popup_1073db59a87adca7a22a696cc5e6d6f6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gdf.sjoin_nearest(gdf.copy(), distance_col="nearest")
# Out:
#    id_left  long_left   lat_left                geometry  index_right
# 0        1 -73.582003  45.504592  POINT (-73.582 45.505)            0  \
# 1        2 -73.587419  45.503420  POINT (-73.587 45.503)            1
# 2        3 -73.586842  45.503720  POINT (-73.587 45.504)            2
# 3        4 -73.587095  45.502097  POINT (-73.587 45.502)            3
#
#    id_right  long_right  lat_right  nearest
# 0         1  -73.582003  45.504592      0.0
# 1         2  -73.587419  45.503420      0.0
# 2         3  -73.586842  45.503720      0.0
# 3         4  -73.587095  45.502097      0.0

# %%
# import numpy as np
# from scipy.spatial import KDTree

# df = pd.DataFrame({
#     'id': [1, 2, 3, 4],
#     'long': [-73.582003, -73.587419, -73.586842, -73.587095],
#     'lat': [45.504592, 45.503420, 45.503720, 45.502097]})

# gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.long, df.lat))
# gdf = gdf.set_crs('epsg:32188')

# # Create a KDTree from the points in the GeoDataFrame
# tree = KDTree(gdf.geometry.values.data)

# # Query the tree to find the distance from each point to its nearest neighbor
# distances, indices = tree.query(gdf.geometry.values.data, k=2)

# # Create a new DataFrame with the distances to the nearest neighbor
# result = pd.DataFrame({
#     'id_left': gdf['id'],
#     'distance': distances[:, 1]
# })

# print(result)

# %%
from scipy.spatial import KDTree

# Extract the coordinates of each point in the GeoDataFrame
coords = gdf.geometry.apply(lambda p: [p.x, p.y]).tolist()

# Create a NumPy array from the coordinates
data = np.array(coords)

# Create a KDTree from the NumPy array
tree = KDTree(data)

# Query the tree to find the distance from each point to its nearest neighbor
distances, indices = tree.query(data, k=2)

# Extract the distance to the second nearest neighbor (the first nearest neighbor is always the point itself)
distances = distances[:, 1]

# Add the distances to the original GeoDataFrame
gdf['distance'] = distances

# %%
gdf
# Out:
#    id       long        lat                geometry  distance
# 0   1 -73.582003  45.504592  POINT (-73.582 45.505)  0.004917
# 1   2 -73.587419  45.503420  POINT (-73.587 45.503)  0.000650
# 2   3 -73.586842  45.503720  POINT (-73.587 45.504)  0.000650
# 3   4 -73.587095  45.502097  POINT (-73.587 45.502)  0.001362
