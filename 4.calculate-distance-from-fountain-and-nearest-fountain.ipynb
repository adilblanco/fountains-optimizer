# %%
import os
import folium
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Polygon

from utils import *

# %% [markdown]
# ### Fountain

# %%
fountains = pd.read_csv(os.getenv("fountains"))
fountains.columns = fountains.columns.str.lower()

# %%
fountains = gpd.GeoDataFrame(fountains, geometry=gpd.points_from_xy(fountains.longitude, fountains.latitude))

# %%
print(fountains.crs)
# Out:
# None

# %%
fountains = fountains.set_crs('epsg:4326')

# %%
print(fountains.crs)
# Out:
# epsg:4326

# %% [markdown]
# ### calcul the distance between fountain and closest one

# %%
# fountains_utm = fountains.to_crs(epsg=32188)

# %%
from scipy.spatial import cKDTree

# Create a KDTree from the geometry of the GeoDataFrame
tree = cKDTree(np.array(fountains.geometry.apply(lambda geom: [geom.x, geom.y])).tolist())

# Query the tree for the closest points to each point in the GeoDataFrame
distances, indices = tree.query(np.array(fountains.geometry.apply(lambda geom: [geom.x, geom.y])).tolist(), k=2)

# Get the closest point for each row
fountains['closest_point'] = fountains.geometry.iloc[indices[:, 1]].values

# %%
from geopy.distance import distance

def get_distance(row):
    point = row['geometry']
    closest_point = row['closest_point']
    return distance((point.y, point.x), (closest_point.y, closest_point.x)).meters

# %%
fountains["closest_fountain"] = fountains.apply(get_distance, axis=1)

# %%
fountains[fountains.nom_parc_lieu.str.contains("Royal", na=False)]
# Out:
#       id arrondissement               nom_parc_lieu proximité_jeux_repère  \
# 620  631    Ville-Marie  près du parc du Mont-Royal                   NaN
# 827  841    Ville-Marie               du Mont-Royal                chalet
# 828  842    Ville-Marie               du Mont-Royal                chalet
# 829  843    Ville-Marie               du Mont-Royal               sentier
# 830  844    Ville-Marie               du Mont-Royal                chemin
# 831  845    Ville-Marie               du Mont-Royal                chalet
# 832  846    Ville-Marie               du Mont-Royal                chalet
# 833  847    Ville-Marie               du Mont-Royal                chalet
# 834  848    Ville-Marie               du Mont-Royal                chemin
# 835  849    Ville-Marie               du Mont-Royal               sentier
# 836  850    Ville-Marie               du Mont-Royal         stationnement
# 837  851    Ville-Marie               du Mont-Royal                   NaN
# 838  852    Ville-Marie               du Mont-Royal                   NaN
# 839  853    Ville-Marie               du Mont-Royal               sentier
# 840  854    Ville-Marie               du Mont-Royal               sentier
# 841  855    Ville-Marie               du Mont-Royal                   NaN
# 842  856    Ville-Marie               du Mont-Royal                   NaN
# 843  857    Ville-Marie               du Mont-Royal                   NaN
# 846  860    Ville-Marie               du Mont-Royal               sentier
#
#                             intersection  etat  date_installation  \
# 620          ave des Pins Ouest/rue Peel   NaN                NaN
# 827                                  NaN   NaN                NaN
# 828                                  NaN   NaN                NaN
# 829                                  NaN   NaN                NaN
# 830                                  NaN   NaN                NaN
# 831                                  NaN   NaN                NaN
# 832                                  NaN   NaN                NaN
# 833              près du lac des castors   NaN                NaN
# 834                                  NaN   NaN                NaN
# 835              près du lac des castors   NaN                NaN
# 836                                  NaN   NaN                NaN
# 837  ave du Parc/rue Prince Arthur Ouest   NaN                NaN
# 838        près de rue Hill Parck Circle   NaN                NaN
# 839              près du lac des castors   NaN                NaN
# 840              près du lac des castors   NaN                NaN
# 841          ave des Pins Ouest/rue Peel   NaN                NaN
# 842         ave du Parc/ave Duluth Ouest   NaN                NaN
# 843         ave du Parc/ave Duluth Ouest   NaN                NaN
# 846                                  NaN   NaN                NaN
#
#                              remarque precision_localisation          x  \
# 620             au pied de l'escalier     orthophotographies  298391.93
# 827                      Grands Parcs                    NaN  297968.62
# 828                      Grands Parcs                    NaN  298013.69
# 829                      Grands Parcs                    NaN  297993.79
# 830                      Grands Parcs                    NaN  297633.33
# 831                      Grands Parcs                    NaN  297988.78
# 832                      Grands Parcs                    NaN  297922.91
# 833                      Grands Parcs                    NaN  297051.25
# 834                      Grands Parcs                    NaN  297823.63
# 835                      Grands Parcs                    NaN  297034.91
# 836                      Grands Parcs                    NaN  297497.16
# 837                      Grands Parcs                    NaN  298561.12
# 838                      Grands Parcs                    NaN  297163.55
# 839                      Grands Parcs                    NaN  297217.35
# 840                      Grands Parcs                    NaN  297206.75
# 841                      Grands Parcs                    NaN  298309.17
# 842                      Grands Parcs                    NaN  298102.57
# 843                      Grands Parcs                    NaN  298157.36
# 846  Grands Parcs / auge pour chevaux     orthophotographies  297985.90
#
#               y  longitude   latitude                    geometry  \
# 620  5040522.26 -73.582003  45.504592  POINT (-73.58200 45.50459)
# 827  5040392.46 -73.587419  45.503420  POINT (-73.58742 45.50342)
# 828  5040425.75 -73.586842  45.503720  POINT (-73.58684 45.50372)
# 829  5040245.38 -73.587095  45.502097  POINT (-73.58709 45.50210)
# 830  5040316.15 -73.591708  45.502730  POINT (-73.59171 45.50273)
# 831  5040500.19 -73.587162  45.504390  POINT (-73.58716 45.50439)
# 832  5040477.85 -73.588005  45.504188  POINT (-73.58800 45.50419)
# 833  5039859.87 -73.599150  45.498618  POINT (-73.59915 45.49862)
# 834  5040457.05 -73.589275  45.504000  POINT (-73.58928 45.50400)
# 835  5039898.87 -73.599359  45.498969  POINT (-73.59936 45.49897)
# 836  5040174.42 -73.593449  45.501453  POINT (-73.59345 45.50145)
# 837  5041257.25 -73.579848  45.511207  POINT (-73.57985 45.51121)
# 838  5039699.85 -73.597710  45.497179  POINT (-73.59771 45.49718)
# 839  5039731.56 -73.597022  45.497465  POINT (-73.59702 45.49747)
# 840  5039744.09 -73.597158  45.497578  POINT (-73.59716 45.49758)
# 841  5040579.06 -73.583063  45.505103  POINT (-73.58306 45.50510)
# 842  5041596.63 -73.585721  45.514257  POINT (-73.58572 45.51426)
# 843  5041559.74 -73.585019  45.513926  POINT (-73.58502 45.51393)
# 846  5040244.65 -73.587196  45.502090  POINT (-73.58720 45.50209)
#
#                   closest_point  closest_fountain
# 620  POINT (-73.58306 45.50510)        100.386566
# 827  POINT (-73.58684 45.50372)         56.037072
# 828  POINT (-73.58742 45.50342)         56.037072
# 829  POINT (-73.58720 45.50209)          7.924487
# 830  POINT (-73.59345 45.50145)        196.563830
# 831  POINT (-73.58684 45.50372)         78.505078
# 832  POINT (-73.58716 45.50439)         69.562164
# 833  POINT (-73.59936 45.49897)         42.288895
# 834  POINT (-73.58800 45.50419)        101.445574
# 835  POINT (-73.59915 45.49862)         42.288895
# 836  POINT (-73.59171 45.50273)        196.563830
# 837  POINT (-73.58080 45.51392)        310.980840
# 838  POINT (-73.59716 45.49758)         61.839930
# 839  POINT (-73.59716 45.49758)         16.413848
# 840  POINT (-73.59702 45.49747)         16.413848
# 841  POINT (-73.58200 45.50459)        100.386566
# 842  POINT (-73.58502 45.51393)         66.058187
# 843  POINT (-73.58572 45.51426)         66.058187
# 846  POINT (-73.58709 45.50210)          7.924487

# %%
m = folium.Map(location=[45.5414195, -73.6303031], tiles="cartodbpositron", zoom_start=12)

# %%
part = fountains[fountains.nom_parc_lieu.str.contains("Royal", na=False)]
for _, row in part.iterrows():
    lat = row.latitude
    lon = row.longitude
    folium.Marker(location=[lat, lon], popup=row[["id", "longitude", "latitude"]]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_365511450f7c683b3bfa6ec03eb09e30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_365511450f7c683b3bfa6ec03eb09e30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_365511450f7c683b3bfa6ec03eb09e30 = L.map(
#                 &quot;map_365511450f7c683b3bfa6ec03eb09e30&quot;,
#                 {
#                     center: [45.5414195, -73.6303031],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49a839739c874cf6c331bb2f67290953 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_365511450f7c683b3bfa6ec03eb09e30);
#
#
#             var marker_fc785b185de2369cf337f24603fed3b8 = L.marker(
#                 [45.5045921771973, -73.5820034636704],
#                 {}
#             ).addTo(map_365511450f7c683b3bfa6ec03eb09e30);
#
#
#         var popup_049233fcf9d02ce30e3ade0a6a7fff32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31bdaf16e62c0dc6e92e0353891e7ce1 = $(`&lt;div id=&quot;html_31bdaf16e62c0dc6e92e0353891e7ce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 631 longitude   -73.582003 latitude     45.504592 Name: 620, dtype: object&lt;/div&gt;`)[0];
#                 popup_049233fcf9d02ce30e3ade0a6a7fff32.setContent(html_31bdaf16e62c0dc6e92e0353891e7ce1);
#
#
#
#         marker_fc785b185de2369cf337f24603fed3b8.bindPopup(popup_049233fcf9d02ce30e3ade0a6a7fff32)
#         ;
#
#
#
#
#             var marker_0528906d1ccc545fad3a6343d140edb2 = L.marker(
#                 [45.5034201653086, -73.5874187076881],
#                 {}
#             ).addTo(map_365511450f7c683b3bfa6ec03eb09e30);
#
#
#         var popup_d5e1338a731941dee47e20902610cbfa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87ffcf284c1f3e12b59b262d33cee645 = $(`&lt;div id=&quot;html_87ffcf284c1f3e12b59b262d33cee645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 841 longitude   -73.587419 latitude      45.50342 Name: 827, dtype: object&lt;/div&gt;`)[0];
#                 popup_d5e1338a731941dee47e20902610cbfa.setContent(html_87ffcf284c1f3e12b59b262d33cee645);
#
#
#
#         marker_0528906d1ccc545fad3a6343d140edb2.bindPopup(popup_d5e1338a731941dee47e20902610cbfa)
#         ;
#
#
#
#
#             var marker_492f433c1424abb9a7ea70c92e4895ca = L.marker(
#                 [45.5037201625941, -73.586842424373],
#                 {}
#             ).addTo(map_365511450f7c683b3bfa6ec03eb09e30);
#
#
#         var popup_cee5844df5223b05c772d72dee53c2a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_751c6428499561a39b9012024bbf0b76 = $(`&lt;div id=&quot;html_751c6428499561a39b9012024bbf0b76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 842 longitude   -73.586842 latitude      45.50372 Name: 828, dtype: object&lt;/div&gt;`)[0];
#                 popup_cee5844df5223b05c772d72dee53c2a9.setContent(html_751c6428499561a39b9012024bbf0b76);
#
#
#
#         marker_492f433c1424abb9a7ea70c92e4895ca.bindPopup(popup_cee5844df5223b05c772d72dee53c2a9)
#         ;
#
#
#
#
#             var marker_b3f27017001d4899f463bfb039511f88 = L.marker(
#                 [45.5020969236876, -73.5870945759392],
#                 {}
#             ).addTo(map_365511450f7c683b3bfa6ec03eb09e30);
#
#
#         var popup_a1beef7e8f28252a821a6de7b761305c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7dc8d03ffe348b7c02ad0f8e52a10874 = $(`&lt;div id=&quot;html_7dc8d03ffe348b7c02ad0f8e52a10874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;id                 843 longitude   -73.587095 latitude     45.502097 Name: 829, dtype: object&lt;/div&gt;`)[0];
#                 popup_a1beef7e8f28252a821a6de7b761305c.setContent(html_7dc8d03ffe348b7c02ad0f8e52a10874);
#
#
#
#         marker_b3f27017001d4899f463bfb039511f88.bindPopup(popup_a1beef7e8f28252a821a6de7b761305c)
#         ;
#
#
#
#
#             var marker_6fb628f404551acb4c7c38592080f772 = L.marker(
#                 [45.5027301319067, -73.5917081726892],
#                 {}
#             ).addTo(map_365511450f7c683b3bfa6ec03eb09e30);
#
#
#         var popup_5017e71bf113f591c1c062acc10f8629 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 va

# %%
# https://stackoverflow.com/questions/19412462/getting-distance-between-two-points-based-on-latitude-longitude

from geopy.distance import geodesic


origin = (45.504592, -73.582003)  # (latitude, longitude) don't confuse
dist = (45.505103, -73.583063)

print(geodesic(origin, dist).meters)  # 23576.805481751613
print(geodesic(origin, dist).kilometers)  # 23.576805481751613
print(geodesic(origin, dist).miles)  # 14.64994773134371
# Out:
# 100.43916649131438
# 0.10043916649131439
# 0.0624100046300321

# %%
df = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'long': [-73.582003, -73.587419, -73.586842, -73.587095],
    'lat': [45.504592, 45.503420, 45.503720, 45.502097]})

df
# Out:
#    id       long        lat
# 0   1 -73.582003  45.504592
# 1   2 -73.587419  45.503420
# 2   3 -73.586842  45.503720
# 3   4 -73.587095  45.502097

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.long, df.lat))

# %%
print(gdf.crs)
# Out:
# None

# %%
gdf = gdf.set_crs('epsg:32188')

# %%
print(gdf.crs)
# Out:
# epsg:32188

# %%
gdf.sjoin_nearest(gdf.copy(), distance_col="distance")
# Out:
#    id_left  long_left   lat_left                geometry  index_right  \
# 0        1 -73.582003  45.504592  POINT (-73.582 45.505)            0
# 1        2 -73.587419  45.503420  POINT (-73.587 45.503)            1
# 2        3 -73.586842  45.503720  POINT (-73.587 45.504)            2
# 3        4 -73.587095  45.502097  POINT (-73.587 45.502)            3
#
#    id_right  long_right  lat_right  distance
# 0         1  -73.582003  45.504592       0.0
# 1         2  -73.587419  45.503420       0.0
# 2         3  -73.586842  45.503720       0.0
# 3         4  -73.587095  45.502097       0.0

# %%
m = folium.Map(location=[45.5414195, -73.6303031], tiles="cartodbpositron", zoom_start=12)

# %%
for _, row in gdf.iterrows():
    lat = row.lat
    lon = row.long
    folium.Marker(location=[lat, lon], popup=row["id"]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef3bbd444a5ccc10740318beb98cc797 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef3bbd444a5ccc10740318beb98cc797&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef3bbd444a5ccc10740318beb98cc797 = L.map(
#                 &quot;map_ef3bbd444a5ccc10740318beb98cc797&quot;,
#                 {
#                     center: [45.5414195, -73.6303031],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bc0497f9c55ca939b3529ec115d268e = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef3bbd444a5ccc10740318beb98cc797);
#
#
#             var marker_9ddb9483da70666842e92d35df08b1e8 = L.marker(
#                 [45.504592, -73.582003],
#                 {}
#             ).addTo(map_ef3bbd444a5ccc10740318beb98cc797);
#
#
#         var popup_d11b5062c77e43e14d7fb13480ce54cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_865d3479c985053f448d8cef301703f7 = $(`&lt;div id=&quot;html_865d3479c985053f448d8cef301703f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_d11b5062c77e43e14d7fb13480ce54cb.setContent(html_865d3479c985053f448d8cef301703f7);
#
#
#
#         marker_9ddb9483da70666842e92d35df08b1e8.bindPopup(popup_d11b5062c77e43e14d7fb13480ce54cb)
#         ;
#
#
#
#
#             var marker_d4ef6c33277c0ad09b39d52157907923 = L.marker(
#                 [45.50342, -73.587419],
#                 {}
#             ).addTo(map_ef3bbd444a5ccc10740318beb98cc797);
#
#
#         var popup_fcfa0fa7a1e584cd19ee50716d2f3460 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cc5056767fcb15886bc00dfa43cf003 = $(`&lt;div id=&quot;html_1cc5056767fcb15886bc00dfa43cf003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_fcfa0fa7a1e584cd19ee50716d2f3460.setContent(html_1cc5056767fcb15886bc00dfa43cf003);
#
#
#
#         marker_d4ef6c33277c0ad09b39d52157907923.bindPopup(popup_fcfa0fa7a1e584cd19ee50716d2f3460)
#         ;
#
#
#
#
#             var marker_82a81d52ce2ea2420e22d538a166b14c = L.marker(
#                 [45.50372, -73.586842],
#                 {}
#             ).addTo(map_ef3bbd444a5ccc10740318beb98cc797);
#
#
#         var popup_ec8419f19e621604cb8435c902b4971b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4113b03fdcf8a5d60be7c01faeeff75 = $(`&lt;div id=&quot;html_c4113b03fdcf8a5d60be7c01faeeff75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_ec8419f19e621604cb8435c902b4971b.setContent(html_c4113b03fdcf8a5d60be7c01faeeff75);
#
#
#
#         marker_82a81d52ce2ea2420e22d538a166b14c.bindPopup(popup_ec8419f19e621604cb8435c902b4971b)
#         ;
#
#
#
#
#             var marker_1e972168c4933ee545b4f9588d541fc7 = L.marker(
#                 [45.502097, -73.587095],
#                 {}
#             ).addTo(map_ef3bbd444a5ccc10740318beb98cc797);
#
#
#         var popup_c918516c191818e059a4519109d0a669 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0651f50da451c80082db1024981b9e2e = $(`&lt;div id=&quot;html_0651f50da451c80082db1024981b9e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4&lt;/div&gt;`)[0];
#                 popup_c918516c191818e059a4519109d0a669.setContent(html_0651f50da451c80082db1024981b9e2e);
#
#
#
#         marker_1e972168c4933ee545b4f9588d541fc7.bindPopup(popup_c918516c191818e059a4519109d0a669)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gdf.sjoin_nearest(gdf.copy(), distance_col="nearest")
# Out:
# /Users/ULABIAD/vscode/inf8790-projet/venv/lib/python3.8/site-packages/geopandas/array.py:344: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(
#    id_left  long_left   lat_left                    geometry  index_right  \
# 0        1 -73.582003  45.504592  POINT (-73.58200 45.50459)            0
# 1        2 -73.587419  45.503420  POINT (-73.58742 45.50342)            1
# 2        3 -73.586842  45.503720  POINT (-73.58684 45.50372)            2
# 3        4 -73.587095  45.502097  POINT (-73.58710 45.50210)            3
#
#    id_right  long_right  lat_right  nearest
# 0         1  -73.582003  45.504592      0.0
# 1         2  -73.587419  45.503420      0.0
# 2         3  -73.586842  45.503720      0.0
# 3         4  -73.587095  45.502097      0.0

# %%
# import numpy as np
# from scipy.spatial import KDTree

# df = pd.DataFrame({
#     'id': [1, 2, 3, 4],
#     'long': [-73.582003, -73.587419, -73.586842, -73.587095],
#     'lat': [45.504592, 45.503420, 45.503720, 45.502097]})

# gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.long, df.lat))
# gdf = gdf.set_crs('epsg:32188')

# # Create a KDTree from the points in the GeoDataFrame
# tree = KDTree(gdf.geometry.values.data)

# # Query the tree to find the distance from each point to its nearest neighbor
# distances, indices = tree.query(gdf.geometry.values.data, k=2)

# # Create a new DataFrame with the distances to the nearest neighbor
# result = pd.DataFrame({
#     'id_left': gdf['id'],
#     'distance': distances[:, 1]
# })

# print(result)

# %%
from scipy.spatial import KDTree

# Extract the coordinates of each point in the GeoDataFrame
coords = gdf.geometry.apply(lambda p: [p.x, p.y]).tolist()

# Create a NumPy array from the coordinates
data = np.array(coords)

# Create a KDTree from the NumPy array
tree = KDTree(data)

# Query the tree to find the distance from each point to its nearest neighbor
distances, indices = tree.query(data, k=2)

# Extract the distance to the second nearest neighbor (the first nearest neighbor is always the point itself)
distances = distances[:, 1]

# Add the distances to the original GeoDataFrame
gdf['distance'] = distances
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 13
#      10 tree = KDTree(data)
#      12 # Query the tree to find the distance from each point to its nearest neighbor
# ---> 13 distances, indices = tree.query(data, k=2).meters
#      15 # Extract the distance to the second nearest neighbor (the first nearest neighbor is always the point itself)
#      16 distances = distances[:, 1]
#
# AttributeError: 'tuple' object has no attribute 'meters'

# %%
gdf
# Out:
#    id       long        lat                geometry  distance
# 0   1 -73.582003  45.504592  POINT (-73.582 45.505)  0.004917
# 1   2 -73.587419  45.503420  POINT (-73.587 45.503)  0.000650
# 2   3 -73.586842  45.503720  POINT (-73.587 45.504)  0.000650
# 3   4 -73.587095  45.502097  POINT (-73.587 45.502)  0.001362
